# %% [markdown]
# <a href="https://colab.research.google.com/github/poo100506/-Simple_Python_Programs-/blob/main/Experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def determinant(matrix):
    n = len(matrix)

    # Base case: 1x1 matrix
    if n == 1:
        return matrix[0][0]

    # Base case: 2x2 matrix
    if n == 2:
        return matrix[0][0]*matrix[1][1] - matrix[0][1]*matrix[1][0]

    det = 0

    for col in range(n):
        # Build the minor matrix
        minor = []
        for row in range(1, n):
            minor_row = []
            for c in range(n):
                if c != col:
                    minor_row.append(matrix[row][c])
            minor.append(minor_row)

        # Cofactor expansion
        det += ((-1) ** col) * matrix[0][col] * determinant(minor)

    return det
